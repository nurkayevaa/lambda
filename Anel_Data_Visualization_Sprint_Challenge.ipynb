# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/nurkayevaa/lambda/blob/master/Anel_Data_Visualization_Sprint_Challenge.ipynb)

# %%
# LAMBDA SCHOOL
#
# MACHINE LEARNING
#
# MIT LICENSE

import numpy as np
import pandas as pd

# %% [markdown]
# # Data Visualization Sprint Challenge
#
# There are three objectives in Data Visualization
#
# * Draw an oblique topology
# * Pairplot to find clusters
# * Plot clusters together
#
# Share with mlsubmissions@lambdaschool.com when finished.

# %% [markdown]
# # Draw an oblique topology
#
# The Mexican Hat Filter or Laplacian of Gaussian is used for cleaning up noisy 2d data, such as in images. It makes a pretty cool 3d graph.
#
# Plot the filter that is returned by the defined function. The range of the function as defined should be interesting from approximately -1 to 1

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random


def laplacian_of_gaussian(x,y):
    sigma = 0.3
    return 1/np.pi*sigma * (1-0.5*((x**2 + y**2)/sigma**2)) * np.exp(-((x**2+y**2)/(2*sigma**2)))

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')

x = np.linspace(-1, 1, 60)
y = np.linspace(-1, 1, 60)

x,y = np.meshgrid(x,y)


sequence_containing_z_vals = laplacian_of_gaussian(x,y)


ax.scatter(x, y, sequence_containing_z_vals)
pyplot.show()

# %% [markdown]
# # Pairplot to find clusters
#
# Clusters have a normal shape along each axis. Pairplot the following data and manually print which axes are normal.
#
# Read your data from `https://www.dropbox.com/s/ziqwkm163ih96v0/sprint_challenge_data.csv?raw=1`

# %%
import seaborn as sns

sprint = pd.read_csv('https://www.dropbox.com/s/ziqwkm163ih96v0/sprint_challenge_data.csv?raw=1')


sprint.head()
print(sprint.columns)
plt.figure()
sns.pairplot(data=sprint[['Unnamed: 0', 'na', 'nb', 'lx', 'ly', 'r', 'ny', 'nx']],
             hue="Unnamed: 0", dropna=True)


# Looks like na, nb , ny and nx have normal distribution
# Pairplot via seaborn
# Out:
# Index(['Unnamed: 0', 'na', 'nb', 'lx', 'ly', 'r', 'ny', 'nx'], dtype='object')

# %% [markdown]
# # Plot clusters together
#
# You found the clusters. Draw them on the same graph.

# %%
# Plot clusters

import matplotlib.pyplot as plt

df = pd.read_csv('https://www.dropbox.com/s/ziqwkm163ih96v0/sprint_challenge_data.csv?raw=1')


x=df.iloc[:,1:2]
y=df.iloc[:,2:3]
z=df.iloc[:,6:7]






import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d



plt.figure(figsize=(8,8))
plt.plot(df['lx'], df['ly'], 'o' , label = 'lx on ly' )
plt.plot(df['lx'], df['r'], 'o' , label = 'lx on ly' )

plt.plot(df['na'], df['nb'], 'o' , label = 'lx on ly' )
plt.plot(df['nx'], df['ny'], 'o' , label = 'lx on ly' )
plt.axvline(ls = '-', c = 'blue')

plt.axhline(ls = '-', c = 'blue')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>
