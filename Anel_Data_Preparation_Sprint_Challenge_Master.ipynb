# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/nurkayevaa/lambda/blob/master/Anel_Data_Preparation_Sprint_Challenge_Master.ipynb)

# %% [markdown]
# # Data Preparation
#
# **Due Date:** April 21st @ 12:00 p.m. PST
#
# Below are examples of the Titanic dataset, containing passenger records on board the titanic, and the OKCupid dataset, containing records authorized by OKCupid for use in Machine Learning research.
#
# Your assignment is to combine the results of the Titanic and OKCupid datasets. You should replace each passenger aboard the titanic and their relevant data with a matching individual from the OKCupid dataset.
#
# There should be no duplicates in the remaining dataset, with no NaNs, nulls, or missing information. More specifics at the bottom.

# %%
#The titanic dataset is part of the seaborn package
import numpy as np
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset('titanic')

# The first few records
print(titanic.head(17))
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False

# %%
# 891 passengers with 15 data entries per
print(titanic.shape)
# Out:
# (891, 15)

# %% [markdown]
# ### OKCupid
#
# The OKCupid dataset is 150MB and needs to be downloaded to your Colab session before you can load it. It loads using the same command as the titanic.

# %%
# !wget https://www.dropbox.com/s/kurta6eazegc3su/JSE_OkCupid_profiles.csv?raw=1 -O /tmp/JSE_OkCupid_profiles.csv
# Out:
# --2018-04-21 15:38:24--  https://www.dropbox.com/s/kurta6eazegc3su/JSE_OkCupid_profiles.csv?raw=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/tg6EFjyR44E5TeMvfqEy54agYPH3ospK2AUe8BZaJbFDNAGCo79HE5U5qRoFMskT/file [following]
# --2018-04-21 15:38:24--  https://dl.dropboxusercontent.com/content_link/tg6EFjyR44E5TeMvfqEy54agYPH3ospK2AUe8BZaJbFDNAGCo79HE5U5qRoFMskT/file
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.7.6, 2620:100:601a:6::a27d:706
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.7.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151614805 (145M) [text/csv]
# Saving to: ‘/tmp/JSE_OkCupid_profiles.csv’
#
# /tmp/JSE_OkCupid_pr 100%[===================>] 144.59M  38.4MB/s    in 3.8s
#
# 2018-04-21 15:38:29 (38.4 MB/s) - ‘/tmp/JSE_OkCupid_profiles.csv’ saved [151614805/151614805]

# %%
#Examining the OKCupid dataset
okcupid = pd.read_csv('/tmp/JSE_OkCupid_profiles.csv')

# almost 60000 individuals with 31 columns each
print(okcupid.shape)

# There are many more columns in OKCupid than titanic
print(okcupid.columns)
# Out:
# (59946, 31)
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %%
# The number of unique entries for each column
for column in okcupid.columns:
  print(column, okcupid[column].unique().size)
# Out:
# age 54
# body_type 13
# diet 19
# drinks 7
# drugs 4
# education 33
# essay0 54351
# essay1 51517
# essay2 48636
# essay3 43534
# essay4 49261
# essay5 48964
# essay6 43604
# essay7 45555
# essay8 39325
# essay9 45444
# ethnicity 218
# height 61
# income 13
# job 22
# last_online 30123
# location 199
# offspring 16
# orientation 3
# pets 16
# religion 46
# sex 2
# sign 49
# smokes 6
# speaks 7648
# status 5

# %%
print(okcupid[1:10].isnull())
# Out:
#      age  body_type   diet  drinks  drugs  education  essay0  essay1  essay2  \
# 1  False      False  False   False  False      False   False   False   False
# 2  False      False  False   False   True      False   False   False   False
# 3  False      False  False   False   True      False   False   False   False
# 4  False      False   True   False  False      False   False   False   False
# 5  False      False  False   False   True      False   False   False   False
# 6  False      False  False   False  False      False   False   False   False
# 7  False      False  False   False  False      False    True   False   False
# 8  False       True  False   False   True      False    True   False    True
# 9  False      False  False   False  False      False   False   False   False
#
#    essay3   ...    location  offspring  orientation   pets  religion    sex  \
# 1    True   ...       False      False        False  False     False  False
# 2   False   ...       False       True        False  False      True  False
# 3   False   ...       False      False        False  False      True  False
# 4   False   ...       False       True        False  False      True  False
# 5   False   ...       False      False        False  False     False  False
# 6   False   ...       False       True        False  False      True  False
# 7   False   ...       False      False        False  False     False  False
# 8   False   ...       False      False        False  False     False  False
# 9   False   ...       False       True        False  False     False  False
#
#     sign  smokes  speaks  status
# 1  False   False   False   False
# 2  False   False   False   False
# 3  False   False   False   False
# 4  False   False   False   False
# 5  False   False   False   False
# 6  False    True   False   False
# 7  False   False   False   False
# 8  False   False   False   False
# 9  False   False   False   False
#
# [9 rows x 31 columns]
# nan

# %% [markdown]
# ### Duplicates
#
# There are no duplicates in OKCupid and 107 titanic duplicates.

# %%
print(okcupid.duplicated().sum())
print(titanic.duplicated().sum())
# Out:
# 0
# 107

# %% [markdown]
# ## Instructions
#
# Titanic contains 891 records with 107 duplicates. The final table should contain 784 records. The titanic dataset is also full of  redudant columns: `survived : alive`, `sex : who : adult_male`, which can be identified if they are truly redundant and can be removed if so.
#
# The OKCupid dataset has ~60k records. There are 31 columns that match many of the features (importantly age/sex) in the titanic set.
#
# Update each row of the titanic dataset to contain OKCupid data that matches in demographic information. Select a few columns from the OKCUpid dataset to transfer to the titanic dataset as well to increase the personality of each entry. Do not move the extremely long written records in the OKCupid dataset as part of this process. Those records will be useful later for NLP and text mining.
#
# _Document and justify your decisions!_

# %%
#titanic.loc[titanic.duplicated(), :]
titanic.loc[titanic.duplicated(keep='first'), :]
titanicnd = titanic.drop_duplicates(keep='first')
#print(titanic.head(1))
#print('okcupid')
#print(okcupid.head(1))
okcupid['age'] = okcupid['age'].astype(float)

cleanup_nums = {"sex":     {"m": "male", "f": "female"}}
okcupid.replace(cleanup_nums, inplace=True)



result = pd.merge(titanicnd,
                 okcupid[['sex', 'age', 'pets', 'offspring']],
                 on='age', 
                 how='left')

# %%
result
# Out:
#           survived  pclass   sex  age_x  sibsp  parch  fare embarked  class  \
# 0                0       3  male   22.0      1      0  7.25        S  Third
# 1                0       3  male   22.0      1      0  7.25        S  Third
# 2                0       3  male   22.0      1      0  7.25        S  Third
# 3                0       3  male   22.0      1      0  7.25        S  Third
# 4                0       3  male   22.0      1      0  7.25        S  Third
# 5                0       3  male   22.0      1      0  7.25        S  Third
# 6                0       3  male   22.0      1      0  7.25        S  Third
# 7                0       3  male   22.0      1      0  7.25        S  Third
# 8                0       3  male   22.0      1      0  7.25        S  Third
# 9                0       3  male   22.0      1      0  7.25        S  Third
# 10               0       3  male   22.0      1      0  7.25        S  Third
# 11               0       3  male   22.0      1      0  7.25        S  Third
# 12               0       3  male   22.0      1      0  7.25        S  Third
# 13               0       3  male   22.0      1      0  7.25        S  Third
# 14               0       3  male   22.0      1      0  7.25        S  Third
# 15               0       3  male   22.0      1      0  7.25        S  Third
# 16               0       3  male   22.0      1      0  7.25        S  Third
# 17               0       3  male   22.0      1      0  7.25        S  Third
# 18               0       3  male   22.0      1      0  7.25        S  Third
# 19               0       3  male   22.0      1      0  7.25        S  Third
# 20               0       3  male   22.0      1      0  7.25        S  Third
# 21               0       3  male   22.0      1      0  7.25        S  Third
# 22               0       3  male   22.0      1      0  7.25        S  Third
# 23               0       3  male   22.0      1      0  7.25        S  Third
# 24               0       3  male   22.0      1      0  7.25        S  Third
# 25               0       3  male   22.0      1      0  7.25        S  Third
# 26               0       3  male   22.0      1      0  7.25        S  Third
# 27               0       3  male   22.0      1      0  7.25        S  Third
# 28               0       3  male   22.0      1      0  7.25        S  Third
# 29               0       3  male   22.0      1      0  7.25        S  Third
# ...            ...     ...   ...    ...    ...    ...   ...      ...    ...
# 20673617         0       3  male   32.0      0      0  7.75        Q  Third
# 20673618         0       3  male   32.0      0      0  7.75        Q  Third
# 20673619         0       3  male   32.0      0      0  7.75        Q  Third
# 20673620         0       3  male   32.0      0      0  7.75        Q  Third
# 20673621         0       3  male   32.0      0      0  7.75        Q  Third
# 20673622         0       3  male   32.0      0      0  7.75        Q  Third
# 20673623         0       3  male   32.0      0      0  7.75        Q  Third
# 20673624         0       3  male   32.0      0      0  7.75        Q  Third
# 20673625         0       3  male   32.0      0      0  7.75        Q  Third
# 20673626         0       3  male   32.0      0      0  7.75        Q  Third
# 20673627         0       3  male   32.0      0      0  7.75        Q  Third
# 20673628         0       3  male   32.0      0      0  7.75        Q  Third
# 20673629         0       3  male   32.0      0      0  7.75        Q  Third
# 20673630         0       3  male   32.0      0      0  7.75        Q  Third
# 20673631         0       3  male   32.0      0      0  7.75        Q  Third
# 20673632         0       3  male   32.0      0      0  7.75        Q  Third
# 20673633         0       3  male   32.0      0      0  7.75        Q  Third
# 20673634         0       3  male   32.0      0      0  7.75        Q  Third
# 20673635         0       3  male   32.0      0      0  7.75        Q  Third
# 20673636         0       3  male   32.0      0      0  7.75        Q  Third
# 20673637         0       3  male   32.0      0      0  7.75        Q  Third
# 20673638         0       3  male   32.0      0      0  7.75        Q  Third
# 20673639         0       3  male   32.0      0      0  7.75        Q  Third
# 20673640         0       3  male   32.0      0      0  7.75        Q  Third
# 20673641         0       3  male   32.0      0      0  7.75        Q  Third
# 20673642         0       3  male   32.0      0      0  7.75        Q  Third
# 20673643         0       3  male   32.0      0      0  7.75        Q  Third
# 20673644         0       3  male   32.0      0      0  7.75        Q  Third
# 20673645         0       3  male   32.0      0      0  7.75        Q  Third
# 20673646         0       3  male   32.0      0      0  7.75        Q  Third
#
#           who  adult_male deck  embark_town alive  alone  age_y  \
# 0         man        True  NaN  Southampton    no  False   22.0
# 1         man        True  NaN  Southampton    no  False   35.0
# 2         man        True  NaN  Southampton    no  False   38.0
# 3         man        True  NaN  Southampton    no  False   23.0
# 4         man        True  NaN  Southampton    no  False   29.0
# 5         man        True  NaN  Southampton    no  False   29.0
# 6         man        True  NaN  Southampton    no  False   37.0
# 7         man        True  NaN  Southampton    no  False   35.0
# 8         man        True  NaN  Southampton    no  False   28.0
# 9         man        True  NaN  Southampton    no  False   24.0
# 10        man        True  NaN  Southampton    no  False   33.0
# 11        man        True  NaN  Southampton    no  False   31.0
# 12        man        True  NaN  Southampton    no  False   33.0
# 13        man        True  NaN  Southampton    no  False   30.0
# 14        man        True  NaN  Southampton    no  False   30.0
# 15        man        True  NaN  Southampton    no  False   33.0
# 16        man        True  NaN  Southampton    no  False   28.0
# 17        man        True  NaN  Southampton    no  False   22.0
# 18        man        True  NaN  Southampton    no  False   22.0
# 19        man        True  NaN  Southampton    no  False   30.0
# 20        man        True  NaN  Southampton    no  False   32.0
# 21        man        True  NaN  Southampton    no  False   27.0
# 22        man        True  NaN  Southampton    no  False   27.0
# 23        man        True  NaN  Southampton    no  False   26.0
# 24        man        True  NaN  Southampton    no  False   32.0
# 25        man        True  NaN  Southampton    no  False   25.0
# 26        man        True  NaN  Southampton    no  False   35.0
# 27        man        True  NaN  Southampton    no  False   30.0
# 28        man        True  NaN  Southampton    no  False   35.0
# 29        man        True  NaN  Southampton    no  False   30.0
# ...       ...         ...  ...          ...   ...    ...    ...
# 20673617  man        True  NaN   Queenstown    no   True   31.0
# 20673618  man        True  NaN   Queenstown    no   True   51.0
# 20673619  man        True  NaN   Queenstown    no   True   29.0
# 20673620  man        True  NaN   Queenstown    no   True   32.0
# 20673621  man        True  NaN   Queenstown    no   True   33.0
# 20673622  man        True  NaN   Queenstown    no   True   32.0
# 20673623  man        True  NaN   Queenstown    no   True   19.0
# 20673624  man        True  NaN   Queenstown    no   True   34.0
# 20673625  man        True  NaN   Queenstown    no   True   25.0
# 20673626  man        True  NaN   Queenstown    no   True   23.0
# 20673627  man        True  NaN   Queenstown    no   True   25.0
# 20673628  man        True  NaN   Queenstown    no   True   30.0
# 20673629  man        True  NaN   Queenstown    no   True   32.0
# 20673630  man        True  NaN   Queenstown    no   True   24.0
# 20673631  man        True  NaN   Queenstown    no   True   23.0
# 20673632  man        True  NaN   Queenstown    no   True   28.0
# 20673633  man        True  NaN   Queenstown    no   True   26.0
# 20673634  man        True  NaN   Queenstown    no   True   22.0
# 20673635  man        True  NaN   Queenstown    no   True   29.0
# 20673636  man        True  NaN   Queenstown    no   True   27.0
# 20673637  man        True  NaN   Queenstown    no   True   41.0
# 20673638  man        True  NaN   Queenstown    no   True   24.0
# 20673639  man        True  NaN   Queenstown    no   True   21.0
# 20673640  man        True  NaN   Queenstown    no   True   32.0
# 20673641  man        True  NaN   Queenstown    no   True   48.0
# 20673642  man        True  NaN   Queenstown    no   True   52.0
# 20673643  man        True  NaN   Queenstown    no   True   24.0
# 20673644  man        True  NaN   Queenstown    no   True   42.0
# 20673645  man        True  NaN   Queenstown    no   True   27.0
# 20673646  man        True  NaN   Queenstown    no   True   39.0
#
#                                   pets  \
# 0            likes dogs and likes cats
# 1            likes dogs and likes cats
# 2                             has cats
# 3                           likes cats
# 4            likes dogs and likes cats
# 5                           likes cats
# 6            likes dogs and likes cats
# 7                                  NaN
# 8                           likes cats
# 9                                  NaN
# 10           likes dogs and likes cats
# 11           likes dogs and likes cats
# 12           likes dogs and likes cats
# 13           likes dogs and likes cats
# 14           likes dogs and likes cats
# 15                          likes cats
# 16                            has dogs
# 17        likes dogs and dislikes cats
# 18          has dogs and dislikes cats
# 19           likes dogs and likes cats
# 20                                 NaN
# 21                          likes dogs
# 22           likes dogs and likes cats
# 23                                 NaN
# 24        likes dogs and dislikes cats
# 25           likes dogs and likes cats
# 26                                 NaN
# 27                          likes cats
# 28                                 NaN
# 29                                 NaN
# ...                                ...
# 20673617                           NaN
# 20673618       likes dogs and has cats
# 20673619                           NaN
# 20673620                           NaN
# 20673621                           NaN
# 20673622                           NaN
# 20673623                           NaN
# 20673624                           NaN
# 20673625                           NaN
# 20673626                           NaN
# 20673627                    likes cats
# 20673628                           NaN
# 20673629                      has dogs
# 20673630                    likes dogs
# 20673631                           NaN
# 20673632                    likes dogs
# 20673633     likes dogs and likes cats
# 20673634                           NaN
# 20673635                           NaN
# 20673636       has dogs and likes cats
# 20673637     likes dogs and likes cats
# 20673638                    likes dogs
# 20673639         has dogs and has cats
# 20673640                           NaN
# 20673641     likes dogs and likes cats
# 20673642       likes dogs and has cats
# 20673643     likes dogs and likes cats
# 20673644                           NaN
# 20673645     likes dogs and likes cats
# 20673646     likes dogs and likes cats
#
#                                              offspring
# 0         doesn&rsquo;t have kids, but might want them
# 1         doesn&rsquo;t have kids, but might want them
# 2                                                  NaN
# 3                              doesn&rsquo;t want kids
# 4                                                  NaN
# 5         doesn&rsquo;t have kids, but might want them
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                              doesn&rsquo;t have kids
# 10                                                 NaN
# 11                                                 NaN
# 12                             doesn&rsquo;t have kids
# 13        doesn&rsquo;t have kids, but might want them
# 14                                                 NaN
# 15                                                 NaN
# 16             doesn&rsquo;t have kids, but wants them
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21             doesn&rsquo;t have kids, but wants them
# 22                                                 NaN
# 23                                                 NaN
# 24             doesn&rsquo;t have kids, but wants them
# 25        doesn&rsquo;t have kids, but might want them
# 26                                                 NaN
# 27                             doesn&rsquo;t have kids
# 28             doesn&rsquo;t have kids, but wants them
# 29                                                 NaN
# ...                                                ...
# 20673617                                           NaN
# 20673618                                           NaN
# 20673619                       doesn&rsquo;t have kids
# 20673620                                      has kids
# 20673621                                           NaN
# 20673622                                           NaN
# 20673623                                           NaN
# 20673624                                           NaN
# 20673625                                           NaN
# 20673626                                           NaN
# 20673627                                           NaN
# 20673628                       doesn&rsquo;t have kids
# 20673629                                           NaN
# 20673630                       doesn&rsquo;t have kids
# 20673631                                           NaN
# 20673632                                           NaN
# 20673633                                           NaN
# 20673634       doesn&rsquo;t have kids, but wants them
# 20673635                                           NaN
# 20673636                                           NaN
# 20673637                                           NaN
# 20673638                                           NaN
# 20673639                       doesn&rsquo;t want kids
# 20673640                                           NaN
# 20673641                       doesn&rsquo;t have kids
# 20673642                       doesn&rsquo;t want kids
# 20673643                       doesn&rsquo;t have kids
# 20673644                       doesn&rsquo;t have kids
# 20673645       doesn&rsquo;t have kids, but wants them
# 20673646                                           NaN
#
# [20673647 rows x 18 columns]

# %% [markdown]
# ### Benchmark
#
# The titanic dataset is very popular for beginning Data Science training.
#
# Your final dataset should perfectly match these two obvious and famous benchmarks of the titanic data, with other new, interesting analysis available from your combinations:

# %%
titanicnd.groupby('sex')[['survived']].mean()
result.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.740614
# male    0.219347

# %%
titanic.groupby(['sex', 'class'])['survived'].aggregate('mean').unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# ### Suggested search terms
#
# python pandas replace columns
#
# python pandas concatenate columns
#
# python pandas concatenate rows
#
# python pandas remove duplicates
#
# python pandas merge and join records
